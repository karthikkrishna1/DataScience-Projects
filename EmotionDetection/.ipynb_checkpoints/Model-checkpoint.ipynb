# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import tensorflow_hub as hub

# %%
root_dir = os.path.abspath(os.path.join(os.pardir,'datasets','EmotionDetection'))

# %%
os.listdir(os.path.abspath(os.path.join(root_dir, 'train','angry')))
# Out:
# ['0.jpg',
#  '1.jpg',
#  '10.jpg',
#  '10002.jpg',
#  '10016.jpg',
#  '10037.jpg',
#  '10038.jpg',
#  '10057.jpg',
#  '10063.jpg',
#  '10069.jpg',
#  '10100.jpg',
#  '10105.jpg',
#  '10115.jpg',
#  '10122.jpg',
#  '10142.jpg',
#  '1015.jpg',
#  '10154.jpg',
#  '10155.jpg',
#  '10158.jpg',
#  '1016.jpg',
#  '10167.jpg',
#  '10178.jpg',
#  '1018.jpg',
#  '10181.jpg',
#  '10192.jpg',
#  '10196.jpg',
#  '10202.jpg',
#  '10207.jpg',
#  '10214.jpg',
#  '10223.jpg',
#  '10226.jpg',
#  '10240.jpg',
#  '10242.jpg',
#  '10250.jpg',
#  '10251.jpg',
#  '10253.jpg',
#  '10265.jpg',
#  '10287.jpg',
#  '10302.jpg',
#  '10310.jpg',
#  '10325.jpg',
#  '10348.jpg',
#  '10359.jpg',
#  '10363.jpg',
#  '10364.jpg',
#  '10373.jpg',
#  '10377.jpg',
#  '10378.jpg',
#  '10385.jpg',
#  '10388.jpg',
#  '1039.jpg',
#  '10394.jpg',
#  '10397.jpg',
#  '10401.jpg',
#  '10420.jpg',
#  '10429.jpg',
#  '10430.jpg',
#  '10431.jpg',
#  '10439.jpg',
#  '10440.jpg',
#  '10441.jpg',
#  '10462.jpg',
#  '10472.jpg',
#  '10475.jpg',
#  '10490.jpg',
#  '10497.jpg',
#  '1051.jpg',
#  '10510.jpg',
#  '10511.jpg',
#  '10541.jpg',
#  '10544.jpg',
#  '10548.jpg',
#  '10563.jpg',
#  '10573.jpg',
#  '10592.jpg',
#  '10595.jpg',
#  '10603.jpg',
#  '10604.jpg',
#  '1061.jpg',
#  '10616.jpg',
#  '10619.jpg',
#  '10623.jpg',
#  '10626.jpg',
#  '10651.jpg',
#  '10656.jpg',
#  '1066.jpg',
#  '10661.jpg',
#  '10666.jpg',
#  '10682.jpg',
#  '10692.jpg',
#  '107.jpg',
#  '10714.jpg',
#  '10716.jpg',
#  '10726.jpg',
#  '10729.jpg',
#  '10771.jpg',
#  '10785.jpg',
#  '10786.jpg',
#  '10790.jpg',
#  '10805.jpg',
#  '10812.jpg',
#  '10814.jpg',
#  '10819.jpg',
#  '10821.jpg',
#  '10831.jpg',
#  '10851.jpg',
#  '10874.jpg',
#  '10889.jpg',
#  '10890.jpg',
#  '10894.jpg',
#  '1090.jpg',
#  '10900.jpg',
#  '10904.jpg',
#  '10907.jpg',
#  '10908.jpg',
#  '10913.jpg',
#  '10915.jpg',
#  '10918.jpg',
#  '10925.jpg',
#  '10928.jpg',
#  '10939.jpg',
#  '10942.jpg',
#  '10947.jpg',
#  '10959.jpg',
#  '10961.jpg',
#  '10965.jpg',
#  '10973.jpg',
#  '1098.jpg',
#  '10984.jpg',
#  '10988.jpg',
#  '10989.jpg',
#  '10994.jpg',
#  '11004.jpg',
#  '11008.jpg',
#  '11011.jpg',
#  '11014.jpg',
#  '11018.jpg',
#  '1102.jpg',
#  '11042.jpg',
#  '1105.jpg',
#  '11053.jpg',
#  '11060.jpg',
#  '1108.jpg',
#  '11083.jpg',
#  '11102.jpg',
#  '11109.jpg',
#  '11113.jpg',
#  '11117.jpg',
#  '11118.jpg',
#  '11151.jpg',
#  '11153.jpg',
#  '11174.jpg',
#  '11181.jpg',
#  '11190.jpg',
#  '11205.jpg',
#  '11206.jpg',
#  '11215.jpg',
#  '1122.jpg',
#  '1123.jpg',
#  '11235.jpg',
#  '11258.jpg',
#  '11267.jpg',
#  '11268.jpg',
#  '11274.jpg',
#  '11286.jpg',
#  '11289.jpg',
#  '11301.jpg',
#  '11315.jpg',
#  '11325.jpg',
#  '11377.jpg',
#  '11379.jpg',
#  '11385.jpg',
#  '11386.jpg',
#  '11389.jpg',
#  '11403.jpg',
#  '11410.jpg',
#  '11411.jpg',
#  '11420.jpg',
#  '11426.jpg',
#  '11432.jpg',
#  '11449.jpg',
#  '11458.jpg',
#  '11460.jpg',
#  '11464.jpg',
#  '1147.jpg',
#  '11474.jpg',
#  '11475.jpg',
#  '11480.jpg',
#  '1150.jpg',
#  '11534.jpg',
#  '11537.jpg',
#  '11545.jpg',
#  '11548.jpg',
#  '11550.jpg',
#  '11557.jpg',
#  '11571.jpg',
#  '11572.jpg',
#  '11577.jpg',
#  '1158.jpg',
#  '1160.jpg',
#  '11606.jpg',
#  '11607.jpg',
#  '11617.jpg',
#  '11623.jpg',
#  '11641.jpg',
#  '11644.jpg',
#  '11645.jpg',
#  '11647.jpg',
#  '1166.jpg',
#  '11669.jpg',
#  '1168.jpg',
#  '11688.jpg',
#  '117.jpg',
#  '1170.jpg',
#  '11707.jpg',
#  '11708.jpg',
#  '11714.jpg',
#  '11732.jpg',
#  '11735.jpg',
#  '11744.jpg',
#  '11755.jpg',
#  '11756.jpg',
#  '11759.jpg',
#  '11764.jpg',
#  '11769.jpg',
#  '1178.jpg',
#  '11781.jpg',
#  '11805.jpg',
#  '1181.jpg',
#  '11820.jpg',
#  '11825.jpg',
#  '11863.jpg',
#  '11877.jpg',
#  '11882.jpg',
#  '11887.jpg',
#  '11898.jpg',
#  '11905.jpg',
#  '11918.jpg',
#  '1192.jpg',
#  '11922.jpg',
#  '11929.jpg',
#  '1194.jpg',
#  '11959.jpg',
#  '11965.jpg',
#  '120.jpg',
#  '1200.jpg',
#  '12016.jpg',
#  '12022.jpg',
#  '12025.jpg',
#  '12027.jpg',
#  '12034.jpg',
#  '1204.jpg',
#  '12048.jpg',
#  '12049.jpg',
#  '12055.jpg',
#  '12075.jpg',
#  '1210.jpg',
#  '1211.jpg',
#  '12110.jpg',
#  '12118.jpg',
#  '12124.jpg',
#  '1213.jpg',
#  '12133.jpg',
#  '12142.jpg',
#  '12146.jpg',
#  '12155.jpg',
#  '1216.jpg',
#  '12181.jpg',
#  '12196.jpg',
#  '12198.jpg',
#  '122.jpg',
#  '12203.jpg',
#  '12206.jpg',
#  '1221.jpg',
#  '12211.jpg',
#  '12213.jpg',
#  '12218.jpg',
#  '12222.jpg',
#  '12231.jpg',
#  '12235.jpg',
#  '12249.jpg',
#  '1225.jpg',
#  '12254.jpg',
#  '1226.jpg',
#  '12262.jpg',
#  '12270.jpg',
#  '12275.jpg',
#  '12283.jpg',
#  '12294.jpg',
#  '12298.jpg',
#  '123.jpg',
#  '12304.jpg',
#  '12310.jpg',
#  '12314.jpg',
#  '12316.jpg',
#  '12328.jpg',
#  '1233.jpg',
#  '12365.jpg',
#  '12367.jpg',
#  '12375.jpg',
#  '12392.jpg',
#  '12400.jpg',
#  '12404.jpg',
#  '12419.jpg',
#  '1242.jpg',
#  '12421.jpg',
#  '12432.jpg',
#  '12443.jpg',
#  '12450.jpg',
#  '12451.jpg',
#  '12456.jpg',
#  '12459.jpg',
#  '12469.jpg',
#  '12474.jpg',
#  '12475.jpg',
#  '12476.jpg',
#  '12483.jpg',
#  '12494.jpg',
#  '1250.jpg',
#  '12503.jpg',
#  '12511.jpg',
#  '1252.jpg',
#  '12525.jpg',
#  '12532.jpg',
#  '12540.jpg',
#  '12543.jpg',
#  '1255.jpg',
#  '12552.jpg',
#  '12584.jpg',
#  '12585.jpg',
#  '12595.jpg',
#  '126.jpg',
#  '12613.jpg',
#  '12616.jpg',
#  '12622.jpg',
#  '12633.jpg',
#  '12635.jpg',
#  '12644.jpg',
#  '12645.jpg',
#  '12666.jpg',
#  '12667.jpg',
#  '12669.jpg',
#  '1267.jpg',
#  '12675.jpg',
#  '12679.jpg',
#  '1268.jpg',
#  '12681.jpg',
#  '12688.jpg',
#  '12693.jpg',
#  '12710.jpg',
#  '12735.jpg',
#  '12746.jpg',
#  '12747.jpg',
#  '12751.jpg',
#  '12752.jpg',
#  '12769.jpg',
#  '12770.jpg',
#  '12778.jpg',
#  '12783.jpg',
#  '12817.jpg',
#  '12846.jpg',
#  '12853.jpg',
#  '12855.jpg',
#  '12860.jpg',
#  '12863.jpg',
#  '12874.jpg',
#  '12876.jpg',
#  '12889.jpg',
#  '12915.jpg',
#  '12947.jpg',
#  '12962.jpg',
#  '12968.jpg',
#  '12970.jpg',
#  '12971.jpg',
#  '12972.jpg',
#  '12975.jpg',
#  '12984.jpg',
#  '12989.jpg',
#  '1299.jpg',
#  '13001.jpg',
#  '13013.jpg',
#  '13019.jpg',
#  '13022.jpg',
#  '13038.jpg',
#  '13055.jpg',
#  '13075.jpg',
#  '1308.jpg',
#  '13094.jpg',
#  '13095.jpg',
#  '1311.jpg',
#  '13125.jpg',
#  '13128.jpg',
#  '13134.jpg',
#  '13141.jpg',
#  '13148.jpg',
#  '13149.jpg',
#  '13159.jpg',
#  '1317.jpg',
#  '13182.jpg',
#  '13190.jpg',
#  '13201.jpg',
#  '13207.jpg',
#  '13208.jpg',
#  '13210.jpg',
#  '13216.jpg',
#  '13223.jpg',
#  '13224.jpg',
#  '13238.jpg',
#  '13239.jpg',
#  '13256.jpg',
#  '13297.jpg',
#  '13324.jpg',
#  '13345.jpg',
#  '13352.jpg',
#  '13355.jpg',
#  '1338.jpg',
#  '13386.jpg',
#  '13391.jpg',
#  '13399.jpg',
#  '134.jpg',
#  '13402.jpg',
#  '13403.jpg',
#  '13408.jpg',
#  '13415.jpg',
#  '13416.jpg',
#  '13418.jpg',
#  '13425.jpg',
#  '13437.jpg',
#  '13442.jpg',
#  '13451.jpg',
#  '13452.jpg',
#  '13463.jpg',
#  '13478.jpg',
#  '13481.jpg',
#  '1349.jpg',
#  '13499.jpg',
#  '13503.jpg',
#  '13511.jpg',
#  '13517.jpg',
#  '13543.jpg',
#  '13550.jpg',
#  '13559.jpg',
#  '13568.jpg',
#  '13577.jpg',
#  '13621.jpg',
#  '13636.jpg',
#  '13640.jpg',
#  '1365.jpg',
#  '13673.jpg',
#  '13675.jpg',
#  '13676.jpg',
#  '13680.jpg',
#  '1370.jpg',
#  '1372.jpg',
#  '1373.jpg',
#  '13735.jpg',
#  '1374.jpg',
#  '13742.jpg',
#  '13745.jpg',
#  '13746.jpg',
#  '13748.jpg',
#  '1375.jpg',
#  '13768.jpg',
#  '13770.jpg',
#  '13778.jpg',
#  '13781.jpg',
#  '13787.jpg',
#  '13791.jpg',
#  '13797.jpg',
#  '13809.jpg',
#  '13831.jpg',
#  '1384.jpg',
#  '13844.jpg',
#  '13858.jpg',
#  '13861.jpg',
#  '13862.jpg',
#  '13892.jpg',
#  '13902.jpg',
#  '13903.jpg',
#  '1392.jpg',
#  '13926.jpg',
#  '1393.jpg',
#  '13934.jpg',
#  '13936.jpg',
#  '13941.jpg',
#  '13942.jpg',
#  '13948.jpg',
#  '13950.jpg',
#  '13951.jpg',
#  '13952.jpg',
#  '13956.jpg',
#  '13958.jpg',
#  '1396.jpg',
#  '13961.jpg',
#  '13967.jpg',
#  '1397.jpg',
#  '13981.jpg',
#  '14008.jpg',
#  '14018.jpg',
#  '14029.jpg',
#  '14046.jpg',
#  '14056.jpg',
#  '14061.jpg',
#  '14064.jpg',
#  '14071.jpg',
#  '14083.jpg',
#  '14085.jpg',
#  '14095.jpg',
#  '14096.jpg',
#  '14104.jpg',
#  '1412.jpg',
#  '14126.jpg',
#  '14129.jpg',
#  '1413.jpg',
#  '14137.jpg',
#  '14142.jpg',
#  '14143.jpg',
#  '14147.jpg',
#  '14164.jpg',
#  '14166.jpg',
#  '14168.jpg',
#  '14172.jpg',
#  '14179.jpg',
#  '14184.jpg',
#  '14196.jpg',
#  '14202.jpg',
#  '14213.jpg',
#  '14215.jpg',
#  '14217.jpg',
#  '14221.jpg',
#  '14248.jpg',
#  '14266.jpg',
#  '14296.jpg',
#  '14299.jpg',
#  '14304.jpg',
#  '14312.jpg',
#  '14313.jpg',
#  '14338.jpg',
#  '14344.jpg',
#  '14353.jpg',
#  '14359.jpg',
#  '14368.jpg',
#  '14412.jpg',
#  '14416.jpg',
#  '14426.jpg',
#  '1443.jpg',
#  '14439.jpg',
#  '1444.jpg',
#  '14445.jpg',
#  '14453.jpg',
#  '14460.jpg',
#  '14478.jpg',
#  '1448.jpg',
#  '14482.jpg',
#  '1450.jpg',
#  '14501.jpg',
#  '14511.jpg',
#  '14526.jpg',
#  '1453.jpg',
#  '14575.jpg',
#  '14583.jpg',
#  '14599.jpg',
#  '14603.jpg',
#  '14604.jpg',
#  '14614.jpg',
#  '14616.jpg',
#  '1462.jpg',
#  '14638.jpg',
#  '14640.jpg',
#  '14661.jpg',
#  '14667.jpg',
#  '14669.jpg',
#  '14679.jpg',
#  '1468.jpg',
#  '14698.jpg',
#  '14709.jpg',
#  '14719.jpg',
#  '14739.jpg',
#  '14752.jpg',
#  '14758.jpg',
#  '14763.jpg',
#  '14768.jpg',
#  '14773.jpg',
#  '14776.jpg',
#  '14778.jpg',
#  '14791.jpg',
#  '14801.jpg',
#  '14807.jpg',
#  '14826.jpg',
#  '14827.jpg',
#  '1483.jpg',
#  '14856.jpg',
#  '14864.jpg',
#  '14865.jpg',
#  '14873.jpg',
#  '149.jpg',
#  '1490.jpg',
#  '14928.jpg',
#  '14936.jpg',
#  '14937.jpg',
#  '14961.jpg',
#  '14976.jpg',
#  '14977.jpg',
#  '14989.jpg',
#  '14993.jpg',
#  '150.jpg',
#  '15000.jpg',
#  '15002.jpg',
#  '15005.jpg',
#  '15014.jpg',
#  '15020.jpg',
#  '15023.jpg',
#  '15048.jpg',
#  '15055.jpg',
#  '15064.jpg',
#  '15068.jpg',
#  '15069.jpg',
#  '15080.jpg',
#  '15083.jpg',
#  '15089.jpg',
#  '15111.jpg',
#  '15112.jpg',
#  '15122.jpg',
#  '1513.jpg',
#  '15133.jpg',
#  '15136.jpg',
#  '15139.jpg',
#  '15157.jpg',
#  '15160.jpg',
#  '1520.jpg',
#  '1522.jpg',
#  '15223.jpg',
#  '15261.jpg',
#  '15262.jpg',
#  '15273.jpg',
#  '15278.jpg',
#  '15297.jpg',
#  '15318.jpg',
#  '15321.jpg',
#  '15325.jpg',
#  '15327.jpg',
#  '1533.jpg',
#  '15330.jpg',
#  '15344.jpg',
#  '15345.jpg',
#  '15352.jpg',
#  '15359.jpg',
#  '15363.jpg',
#  '15368.jpg',
#  '15381.jpg',
#  '15385.jpg',
#  '15390.jpg',
#  '15391.jpg',
#  '15395.jpg',
#  '15399.jpg',
#  '15404.jpg',
#  '15410.jpg',
#  '15413.jpg',
#  '15418.jpg',
#  '15433.jpg',
#  '15444.jpg',
#  '15464.jpg',
#  '15465.jpg',
#  '15471.jpg',
#  '15478.jpg',
#  '15480.jpg',
#  '15482.jpg',
#  '15490.jpg',
#  '15505.jpg',
#  '15526.jpg',
#  '15552.jpg',
#  '15557.jpg',
#  '1556.jpg',
#  '15569.jpg',
#  '15575.jpg',
#  '1558.jpg',
#  '15593.jpg',
#  '15594.jpg',
#  '15596.jpg',
#  '15610.jpg',
#  '15612.jpg',
#  '15620.jpg',
#  '15625.jpg',
#  '1564.jpg',
#  '15650.jpg',
#  '15659.jpg',
#  '15662.jpg',
#  '15688.jpg',
#  '15689.jpg',
#  '15692.jpg',
#  '15700.jpg',
#  '15706.jpg',
#  '15719.jpg',
#  '15726.jpg',
#  '15739.jpg',
#  '15743.jpg',
#  '15763.jpg',
#  '15769.jpg',
#  '15779.jpg',
#  '15805.jpg',
#  '15807.jpg',
#  '15825.jpg',
#  '15836.jpg',
#  '15839.jpg',
#  '15842.jpg',
#  '15844.jpg',
#  '15849.jpg',
#  '1586.jpg',
#  '15860.jpg',
#  '1587.jpg',
#  '1588.jpg',
#  '15894.jpg',
#  '15902.jpg',
#  '15903.jpg',
#  '15926.jpg',
#  '15928.jpg',
#  '1593.jpg',
#  '1595.jpg',
#  '15952.jpg',
#  '15962.jpg',
#  '1597.jpg',
#  '15977.jpg',
#  '15988.jpg',
#  '15990.jpg',
#  '15994.jpg',
#  '15997.jpg',
#  '16009.jpg',
#  '16011.jpg',
#  '16012.jpg',
#  '16014.jpg',
#  '16018.jpg',
#  '16027.jpg',
#  '16044.jpg',
#  '16047.jpg',
#  '16073.jpg',
#  '16096.jpg',
#  '16098.jpg',
#  '1610.jpg',
#  '16107.jpg',
#  '16114.jpg',
#  '16124.jpg',
#  '16127.jpg',
#  '16130.jpg',
#  '16137.jpg',
#  '16163.jpg',
#  '16182.jpg',
#  '16186.jpg',
#  '16189.jpg',
#  '16193.jpg',
#  '16197.jpg',
#  '16211.jpg',
#  '16218.jpg',
#  '16228.jpg',
#  '16232.jpg',
#  '16240.jpg',
#  '16253.jpg',
#  '16256.jpg',
#  '16261.jpg',
#  '16263.jpg',
#  '16267.jpg',
#  '16271.jpg',
#  '16283.jpg',
#  '16285.jpg',
#  '16286.jpg',
#  '16289.jpg',
#  '16290.jpg',
#  '16295.jpg',
#  '16297.jpg',
#  '1631.jpg',
#  '16312.jpg',
#  '16316.jpg',
#  '16319.jpg',
#  '16320.jpg',
#  '16323.jpg',
#  '16339.jpg',
#  '16344.jpg',
#  '16354.jpg',
#  '16355.jpg',
#  '16377.jpg',
#  '16378.jpg',
#  '16379.jpg',
#  '16381.jpg',
#  '1639.jpg',
#  '16397.jpg',
#  '1641.jpg',
#  '16414.jpg',
#  '16424.jpg',
#  '16439.jpg',
#  '16468.jpg',
#  '1647.jpg',
#  '16477.jpg',
#  '16481.jpg',
#  '16483.jpg',
#  '16484.jpg',
#  '16490.jpg',
#  '16494.jpg',
#  '16502.jpg',
#  '1651.jpg',
#  '16516.jpg',
#  '16520.jpg',
#  '16527.jpg',
#  '16534.jpg',
#  '16544.jpg',
#  '16560.jpg',
#  '16564.jpg',
#  '16576.jpg',
#  '16603.jpg',
#  '16605.jpg',
#  '16608.jpg',
#  '16626.jpg',
#  '16638.jpg',
#  '16648.jpg',
#  '16652.jpg',
#  '16653.jpg',
#  '16657.jpg',
#  '16662.jpg',
#  '16670.jpg',
#  '16672.jpg',
#  '1668.jpg',
#  '16698.jpg',
#  '16737.jpg',
#  '16739.jpg',
#  '1674.jpg',
#  '16741.jpg',
#  '16746.jpg',
#  '16761.jpg',
#  '16778.jpg',
#  '16806.jpg',
#  '16871.jpg',
#  '16877.jpg',
#  '16884.jpg',
#  '16885.jpg',
#  '16894.jpg',
#  '169.jpg',
#  '16909.jpg',
#  '16910.jpg',
#  '16912.jpg',
#  '16916.jpg',
#  '16917.jpg',
#  '16918.jpg',
#  '16919.jpg',
#  '16929.jpg',
#  '16933.jpg',
#  '1694.jpg',
#  '16941.jpg',
#  '16948.jpg',
#  '16956.jpg',
#  '16958.jpg',
#  '16972.jpg',
#  '16981.jpg',
#  '17000.jpg',
#  '17009.jpg',
#  '17020.jpg',
#  '17049.jpg',
#  '17050.jpg',
#  '17059.jpg',
#  '17090.jpg',
#  '17092.jpg',
#  '1711.jpg',
#  '17111.jpg',
#  '17116.jpg',
#  '17129.jpg',
#  '17139.jpg',
#  '17140.jpg',
#  '17153.jpg',
#  '17155.jpg',
#  '17172.jpg',
#  '17179.jpg',
#  '17181.jpg',
#  '17185.jpg',
#  '17190.jpg',
#  '17204.jpg',
#  '17218.jpg',
#  '17222.jpg',
#  '17223.jpg',
#  '17235.jpg',
#  '17239.jpg',
#  '17254.jpg',
#  '17256.jpg',
#  '1726.jpg',
#  '17262.jpg',
#  '17270.jpg',
#  '17298.jpg',
#  '1731.jpg',
#  '17311.jpg',
#  '17332.jpg',
#  '17335.jpg',
#  '17336.jpg',
#  '1734.jpg',
#  '17352.jpg',
#  '17354.jpg',
#  '17355.jpg',
#  '17377.jpg',
#  '17384.jpg',
#  '17393.jpg',
#  '17410.jpg',
#  '17411.jpg',
#  '17442.jpg',
#  '17448.jpg',
#  '17450.jpg',
#  '17451.jpg',
#  '17473.jpg',
#  '17476.jpg',
#  '17495.jpg',
#  '17496.jpg',
#  '17500.jpg',
#  '17505.jpg',
#  '17509.jpg',
#  '17511.jpg',
#  '17526.jpg',
#  '17527.jpg',
#  '17548.jpg',
#  '17569.jpg',
#  '17571.jpg',
#  '17574.jpg',
#  '17578.jpg',
#  '17589.jpg',
#  '17591.jpg',
#  '17628.jpg',
#  '17629.jpg',
#  '17633.jpg',
#  '17650.jpg',
#  '17659.jpg',
#  '1766.jpg',
#  '17676.jpg',
#  '17679.jpg',
#  '17696.jpg',
#  '17709.jpg',
#  '17712.jpg',
#  '17714.jpg',
#  '17721.jpg',
#  '17723.jpg',
#  '17724.jpg',
#  '17729.jpg',
#  '17733.jpg',
#  '17734.jpg',
#  '17754.jpg',
#  '17756.jpg',
#  '1776.jpg',
#  '17764.jpg',
#  '17768.jpg',
#  '17774.jpg',
#  '17781.jpg',
#  '17785.jpg',
#  '17791.jpg',
#  '17796.jpg',
#  '17797.jpg',
#  '17801.jpg',
#  '17808.jpg',
#  '17810.jpg',
#  '17813.jpg',
#  '17823.jpg',
#  '17829.jpg',
#  '17835.jpg',
#  '17856.jpg',
#  '17860.jpg',
#  '17865.jpg',
#  '17868.jpg',
#  '17881.jpg',
#  '17891.jpg',
#  '1790.jpg',
#  '17903.jpg',
#  '17926.jpg',
#  '17935.jpg',
#  '1794.jpg',
#  '17945.jpg',
#  '17955.jpg',
#  '17964.jpg',
#  '17967.jpg',
#  '17975.jpg',
#  '17981.jpg',
#  '17985.jpg',
#  '17998.jpg',
#  '17999.jpg',
#  '18000.jpg',
#  '18008.jpg',
#  '1802.jpg',
#  '18021.jpg',
#  '18022.jpg',
#  '18032.jpg',
#  '18048.jpg',
#  '18055.jpg',
#  '1806.jpg',
#  '18065.jpg',
#  '18078.jpg',
#  '18081.jpg',
#  '18096.jpg',
#  '1810.jpg',
#  '18107.jpg',
#  '18112.jpg',
#  '18119.jpg',
#  '18122.jpg',
#  '18139.jpg',
#  '18155.jpg',
#  '18156.jpg',
#  '18158.jpg',
#  '18176.jpg',
#  '18177.jpg',
#  '18182.jpg',
#  '18184.jpg',
#  ...]

# %%
example_image_path = os.path.join(root_dir, 'train', 'sad', os.listdir(os.path.join(root_dir, 'train','sad'))[1])

# %%
example_image = plt.imread(example_image_path)
plt.imshow(example_image);

# %%
root_dir
# Out:
# 'C:\\D-Drive\\ComputerScience\\DSProjs\\DataScience-Projects\\datasets\\EmotionDetection'

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1/255., horizontal_flip = True, rotation_range = 45, shear_range = 0.3, zoom_range = 0.3, width_shift_range=0.2, height_shift_range=0.2)

# %%
train_dataset = train_datagen.flow_from_directory(os.path.join(root_dir, 'train'), target_size = (48, 48), batch_size = 128)
# Out:
# Found 28821 images belonging to 7 classes.

# %%
validation_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1/255., horizontal_flip = True, rotation_range = 45, shear_range = 0.3, zoom_range = 0.3, width_shift_range=0.2, height_shift_range=0.2)

# %%
validation_dataset = validation_datagen.flow_from_directory(os.path.join(root_dir, 'validation'), target_size = (48, 48), batch_size = 128)
# Out:
# Found 7066 images belonging to 7 classes.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D( 64, (3 , 3), activation='relu', input_shape = (48, 48, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3 , 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3 , 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation = 'relu'),
    tf.keras.layers.Dense(7, activation = 'softmax')
    
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 46, 46, 64)        1792
#
#  max_pooling2d_6 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 21, 21, 128)       73856
#
#  max_pooling2d_7 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 256)         295168
#
#  max_pooling2d_8 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 128)               524416
#
#  dense_5 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 896,135
# Trainable params: 896,135
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(train_dataset, validation_data = validation_dataset, epochs = 30  )
# Out:
# Epoch 1/30
# 226/226 [==============================] - ETA: 0s - loss: 1.8053 - accuracy: 0.2472WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000022A6F83AD30> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000022A6F83AD30> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 226/226 [==============================] - 594s 3s/step - loss: 1.8053 - accuracy: 0.2472 - val_loss: 1.7840 - val_accuracy: 0.2620
# Epoch 2/30
# 226/226 [==============================] - 182s 808ms/step - loss: 1.7761 - accuracy: 0.2596 - val_loss: 1.7513 - val_accuracy: 0.2777
# Epoch 3/30
# 226/226 [==============================] - 172s 762ms/step - loss: 1.7519 - accuracy: 0.2743 - val_loss: 1.7290 - val_accuracy: 0.3002
# Epoch 4/30
# 226/226 [==============================] - 196s 868ms/step - loss: 1.7195 - accuracy: 0.2987 - val_loss: 1.6957 - val_accuracy: 0.3081
# Epoch 5/30
# 226/226 [==============================] - 200s 887ms/step - loss: 1.6785 - accuracy: 0.3226 - val_loss: 1.6456 - val_accuracy: 0.3455
# Epoch 6/30
# 226/226 [==============================] - 209s 928ms/step - loss: 1.6070 - accuracy: 0.3585 - val_loss: 1.5545 - val_accuracy: 0.3903
# Epoch 7/30
# 226/226 [==============================] - 216s 956ms/step - loss: 1.5486 - accuracy: 0.3918 - val_loss: 1.5463 - val_accuracy: 0.3944
# Epoch 8/30
# 226/226 [==============================] - 202s 891ms/step - loss: 1.5015 - accuracy: 0.4176 - val_loss: 1.4970 - val_accuracy: 0.4193
# Epoch 9/30
# 226/226 [==============================] - 200s 884ms/step - loss: 1.4700 - accuracy: 0.4308 - val_loss: 1.4446 - val_accuracy: 0.4438
# Epoch 10/30
# 226/226 [==============================] - 214s 948ms/step - loss: 1.4381 - accuracy: 0.4428 - val_loss: 1.4459 - val_accuracy: 0.4413
# Epoch 11/30
# 226/226 [==============================] - 222s 982ms/step - loss: 1.4247 - accuracy: 0.4481 - val_loss: 1.4066 - val_accuracy: 0.4583
# Epoch 12/30
# 226/226 [==============================] - 231s 1s/step - loss: 1.4055 - accuracy: 0.4594 - val_loss: 1.3715 - val_accuracy: 0.4827
# Epoch 13/30
# 226/226 [==============================] - 211s 933ms/step - loss: 1.3835 - accuracy: 0.4666 - val_loss: 1.3750 - val_accuracy: 0.4751
# Epoch 14/30
# 226/226 [==============================] - 229s 1s/step - loss: 1.3657 - accuracy: 0.4774 - val_loss: 1.3591 - val_accuracy: 0.4781
# Epoch 15/30
# 226/226 [==============================] - 222s 983ms/step - loss: 1.3468 - accuracy: 0.4815 - val_loss: 1.3433 - val_accuracy: 0.4817
# Epoch 16/30
# 226/226 [==============================] - 213s 945ms/step - loss: 1.3373 - accuracy: 0.4857 - val_loss: 1.3604 - val_accuracy: 0.4840
# Epoch 17/30
# 226/226 [==============================] - 196s 868ms/step - loss: 1.3337 - accuracy: 0.4870 - val_loss: 1.3732 - val_accuracy: 0.4788
# Epoch 18/30
# 226/226 [==============================] - 194s 857ms/step - loss: 1.3259 - accuracy: 0.4918 - val_loss: 1.3202 - val_accuracy: 0.5025
# Epoch 19/30
# 226/226 [==============================] - 1276s 6s/step - loss: 1.3178 - accuracy: 0.4950 - val_loss: 1.3141 - val_accuracy: 0.4935
# Epoch 20/30
# 226/226 [==============================] - 147s 642ms/step - loss: 1.3087 - accuracy: 0.4981 - val_loss: 1.3160 - val_accuracy: 0.4973
# Epoch 21/30
# 226/226 [==============================] - 112s 497ms/step - loss: 1.2962 - accuracy: 0.5067 - val_loss: 1.3087 - val_accuracy: 0.5045
# Epoch 22/30
# 226/226 [==============================] - 121s 536ms/step - loss: 1.2888 - accuracy: 0.5091 - val_loss: 1.3030 - val_accuracy: 0.5000
# Epoch 23/30
# 226/226 [==============================] - 203s 898ms/step - loss: 1.2795 - accuracy: 0.5130 - val_loss: 1.2904 - val_accuracy: 0.5013
# Epoch 24/30
# 226/226 [==============================] - 225s 995ms/step - loss: 1.2688 - accuracy: 0.5135 - val_loss: 1.2825 - val_accuracy: 0.5126
# Epoch 25/30
# 226/226 [==============================] - 231s 1s/step - loss: 1.2698 - accuracy: 0.5164 - val_loss: 1.2736 - val_accuracy: 0.5139
# Epoch 26/30
# 226/226 [==============================] - 188s 831ms/step - loss: 1.2617 - accuracy: 0.5164 - val_loss: 1.2612 - val_accuracy: 0.5139
# Epoch 27/30
# 226/226 [==============================] - 177s 784ms/step - loss: 1.2548 - accuracy: 0.5189 - val_loss: 1.2644 - val_accuracy: 0.5180
# Epoch 28/30
# 226/226 [==============================] - 157s 696ms/step - loss: 1.2521 - accuracy: 0.5225 - val_loss: 1.2892 - val_accuracy: 0.5069
# Epoch 29/30
# 226/226 [==============================] - 159s 705ms/step - loss: 1.2485 - accuracy: 0.5206 - val_loss: 1.2614 - val_accuracy: 0.5178
# Epoch 30/30
# 226/226 [==============================] - 157s 697ms/step - loss: 1.2460 - accuracy: 0.5288 - val_loss: 1.2621 - val_accuracy: 0.5253

# %%
plt.plot(history.history['loss'], label = 'Train Loss')
plt.plot(history.history['val_loss'], label = 'Val Loss')
plt.legend();

# %%
plt.plot(history.history['accuracy'], label = 'Train Accuracy')
plt.plot(history.history['val_accuracy'], label = 'Val Accuracy')
plt.legend();

# %%
## Accuracy only 50 percent. Not a very ideal number. Trying out transfer learning with VGG16

# %%
from tensorflow.keras.applications import ResNet50

# %%
 base_model = tf.keras.applications.DenseNet169(input_shape=(48,48, 3),
                                               include_top=False,
                                               weights="imagenet")

# %%
base_model.trainable = False

# %%
mv2 = tf.keras.Sequential([
    base_model,
    tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(256, activation = 'relu'),
     tf.keras.layers.Dense(128, activation = 'relu'),
     
#     tf.keras.layers.MaxPooling2D(2, 2),
  
    tf.keras.layers.Dense(7, activation = 'softmax')
])

# %%
mv2.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
mv2.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet169 (Functional)    (None, 1, 1, 1664)        12642880
#
#  flatten_3 (Flatten)         (None, 1664)              0
#
#  dense_21 (Dense)            (None, 256)               426240
#
#  dense_22 (Dense)            (None, 128)               32896
#
#  dense_23 (Dense)            (None, 7)                 903
#
# =================================================================
# Total params: 13,102,919
# Trainable params: 460,039
# Non-trainable params: 12,642,880
# _________________________________________________________________

# %%
# Showing a better accuracy

# %%
history_v2 = mv2.fit(train_dataset, validation_data = validation_dataset, epochs = 30  )
# Out:
# Epoch 1/30
# 226/226 [==============================] - ETA: 0s - loss: 1.7303 - accuracy: 0.2926WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000022A03D03A60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000022A03D03A60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 226/226 [==============================] - 866s 4s/step - loss: 1.7303 - accuracy: 0.2926 - val_loss: 1.6967 - val_accuracy: 0.3201
# Epoch 2/30
# 226/226 [==============================] - 457s 2s/step - loss: 1.6915 - accuracy: 0.3171 - val_loss: 1.6706 - val_accuracy: 0.3341
# Epoch 3/30
# 226/226 [==============================] - 442s 2s/step - loss: 1.6745 - accuracy: 0.3283 - val_loss: 1.6702 - val_accuracy: 0.3394
# Epoch 4/30
# 226/226 [==============================] - 410s 2s/step - loss: 1.6658 - accuracy: 0.3377 - val_loss: 1.6615 - val_accuracy: 0.3361
# Epoch 5/30
# 226/226 [==============================] - 426s 2s/step - loss: 1.6576 - accuracy: 0.3356 - val_loss: 1.6629 - val_accuracy: 0.3381
# Epoch 6/30
#  12/226 [>.............................] - ETA: 5:33 - loss: 1.6706 - accuracy: 0.3314
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3100\2425169903.py in <module>
# ----> 1 history_v2 = mv2.fit(train_dataset, validation_data = validation_dataset, epochs = 30  )
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648         This typically includes the forward pass, loss calculation, and metrics
#    1649         updates.
# -> 1650
#    1651         Configuration details for *how* this logic is run (e.g. `tf.function`
#    1652         and `tf.distribute.Strategy` settings), should be left to
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in __call__(self, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   device_name = ctx.device_name
#      51   # pylint: disable=protected-access
# ---> 52   try:
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#
# KeyboardInterrupt:

# %%
test_preds = mv2.predict(validation_dataset)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(validation_dataset.labels,list(map(np.argmax, test_preds)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3100\125394333.py in <module>
# ----> 1 confusion_matrix(validation_dataset.labels,list(map(np.argmax, test_preds)))
#
# NameError: name 'confusion_matrix' is not defined

# %%
plt.plot(history_v2.history['loss'], label = 'Train Loss')
plt.plot(history_v2.history['val_loss'], label = 'Val Loss')
plt.legend();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3100\1961877262.py in <module>
# ----> 1 plt.plot(history_v2.history['loss'], label = 'Train Loss')
#       2 plt.plot(history_v2.history['val_loss'], label = 'Val Loss')
#       3 plt.legend();
#
# NameError: name 'history_v2' is not defined

# %%
plt.plot(history_v2.history['accuracy'], label = 'Train Accuracy')
plt.plot(history_v2.history['val_accuracy'], label = 'Val Accuracy')
plt.legend();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3100\2492551598.py in <module>
# ----> 1 plt.plot(history_v2.history['accuracy'], label = 'Train Accuracy')
#       2 plt.plot(history_v2.history['val_accuracy'], label = 'Val Accuracy')
#       3 plt.legend();
#
# NameError: name 'history_v2' is not defined
